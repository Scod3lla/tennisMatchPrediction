# %% [markdown]
# # Progetto Web Intelligence
# Scodeller Giovanni 864906

# %% [markdown]
# # **NOTES**
#
# 1. Encoding player name is necessary ?
# 2. Wich feature i need to add ?

# %% [markdown]
# # Caricamento Dati e EDA

# %%
# LIBRERIE
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from pandas.api.types import CategoricalDtype
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# CARICAMENTO DATI
def loadDataset(year):
    dataset_path = "../datasets/tennis/"+year+".xlsx"
    return pd.read_excel(dataset_path)

df = loadDataset("2016")
df.index.name   = "Match ID"
df.columns.name = "Attributes"
df.head()
# Out:
# Attributes  ATP  Location              Tournament       Date  Series    Court  \
# Match ID
# 0             1  Brisbane  Brisbane International 2016-01-04  ATP250  Outdoor
# 1             1  Brisbane  Brisbane International 2016-01-04  ATP250  Outdoor
# 2             1  Brisbane  Brisbane International 2016-01-04  ATP250  Outdoor
# 3             1  Brisbane  Brisbane International 2016-01-04  ATP250  Outdoor
# 4             1  Brisbane  Brisbane International 2016-01-05  ATP250  Outdoor
#
# Attributes Surface      Round  Best of       Winner  ...   EXW   EXL   LBW  \
# Match ID                                             ...
# 0             Hard  1st Round        3  Dimitrov G.  ...  1.68  2.10  1.62
# 1             Hard  1st Round        3     Kudla D.  ...  1.58  2.35  1.53
# 2             Hard  1st Round        3     Kamke T.  ...  1.82  1.90  1.80
# 3             Hard  1st Round        3     Chung H.  ...  1.82  1.90  1.73
# 4             Hard  1st Round        3    Goffin D.  ...  1.30  3.40  1.29
#
# Attributes   LBL   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# Match ID
# 0           2.25  1.68  2.31  1.76  2.35  1.66  2.20
# 1           2.50  1.63  2.40  1.63  2.50  1.57  2.37
# 2           2.00  1.90  1.99  1.90  2.10  1.77  2.00
# 3           2.10  1.93  1.96  1.93  2.10  1.82  1.95
# 4           3.75  1.31  3.74  1.31  3.80  1.29  3.56
#
# [5 rows x 40 columns]

# %%
# ESPLORIAMO IL CONTENUTO DI UNA ENTRY
aa = df.loc[140]
for i in df.columns:
    print(i,":", aa[i])
# Out:
# ATP : 6
# Location : Melbourne
# Tournament : Australian Open
# Date : 2016-01-18 00:00:00
# Series : Grand Slam
# Court : Outdoor
# Surface : Hard
# Round : 1st Round
# Best of : 5
# Winner : Goffin D.
# Loser : Stakhovsky S.
# WRank : 16.0
# LRank : 60.0
# WPts : 1835.0
# LPts : 780.0
# W1 : 3.0
# L1 : 6.0
# W2 : 6.0
# L2 : 3.0
# W3 : 6.0
# L3 : 4.0
# W4 : 6.0
# L4 : 4.0
# W5 : nan
# L5 : nan
# Wsets : 3.0
# Lsets : 1.0
# Comment : Completed
# B365W : 1.12
# B365L : 6.0
# EXW : 1.11
# EXL : 5.75
# LBW : 1.12
# LBL : 6.0
# PSW : 1.16
# PSL : 6.1
# MaxW : 1.16
# MaxL : 7.0
# AvgW : 1.13
# AvgL : 5.86

# %%
# VEDIAMO I TIPI DI DATO DELLE FEATURE
df.dtypes
# Out:
# Attributes
# ATP                    int64
# Location              object
# Tournament            object
# Date          datetime64[ns]
# Series                object
# Court                 object
# Surface               object
# Round                 object
# Best of                int64
# Winner                object
# Loser                 object
# WRank                float64
# LRank                float64
# WPts                 float64
# LPts                 float64
# W1                   float64
# L1                   float64
# W2                   float64
# L2                   float64
# W3                   float64
# L3                   float64
# W4                   float64
# L4                   float64
# W5                   float64
# L5                   float64
# Wsets                float64
# Lsets                float64
# Comment               object
# B365W                float64
# B365L                float64
# EXW                  float64
# EXL                  float64
# LBW                  float64
# LBL                  float64
# PSW                  float64
# PSL                  float64
# MaxW                 float64
# MaxL                 float64
# AvgW                 float64
# AvgL                 float64
# dtype: object

# %%
# FEATURE POTENZIALMENTE CATEGORIALI O FATTORIALI
strcol=[]
for col in df.columns:
    if type(df[col][0]) == str:
        strcol.append(col)
strcol
# Out:
# ['Location',
#  'Tournament',
#  'Series',
#  'Court',
#  'Surface',
#  'Round',
#  'Winner',
#  'Loser',
#  'Comment']

# %% [markdown]
# # Funzione per una formattazione generale del dataset
#
# In questa funzione viene anche aggiunto la colonna "target", la feature che andremmo a prevedere

# %%
# Mi serve per sapere l'encoding dei giocatori 
def playEncode(df):
    playerList=set(df["Winner"]) | set(df["Loser"]) # Trovo tutti i giocatori singoli
    
    # Formattazione dei Giocatori
    playerEncode = {}
    for index, player in enumerate(playerList):
        playerEncode[player] = index
        
    return playerEncode

# %%
def generalFormatting(dfCopy, playerEncode):
    
    df = dfCopy.copy()
    
    # Cambio nome delle colonne Winner/Loser
    dictCol = {'Winner' :"Player1", 'Loser':'Player2', 'WRank':'P1_Rank', 'LRank':'P2_Rank', 'WPts':'P1_Pts', 'LPts':'P2_Pts',
       'W1':'P1_S1', 'L1':'P2_S1', 'W2':'P1_S2', "L2":'P2_S2', 'W3':'P1_S3', 'L3':'P2_S3', 'W4':'P1_S4', 'L4':'P2_S4', 'W5':'P1_S5', "L5":'P2_S5', 'Wsets':'P1_sets',
       'Lsets':'P2_sets', 'B365W':'P1_B365', 'B365L':'P2_B365', 'EXW':'P1_EX', 'EXL':'P2_EX', 'LBW':'P1_LB', 'LBL':'P2_LB', 'PSW':'P1_PS',
       'PSL':'P2_PS', 'MaxW':'P1_Max', 'MaxL':'P2_Max', 'AvgW':'P1_Avg', 'AvgL':'P2_Avg'}

    df.rename(columns=dictCol, inplace=True)
    
    df.replace({"Player1":playerEncode, "Player2":playerEncode}, inplace = True)
    
    # Fill NA
    df.fillna(0, inplace = True)
    
    # One Hot Encoding
    df = pd.get_dummies(df, columns = ["Court", "Surface","Comment", "Best of"])
    
    # Encoding Tipo torneo con peso
    df["Series"]=df["Series"].astype('category')
    cats_to_order = ["ATP250", "ATP500", "Masters 1000", "Masters Cup", "Grand Slam"]
    covered_type = CategoricalDtype(categories=cats_to_order, ordered=True)
    df['Series'] = df['Series'].cat.reorder_categories(cats_to_order, ordered=True)
    df["Series"] = df["Series"].cat.codes
    
    # Encoding Round Torneo con peso
    df["Round"]=df["Round"].astype('category')
    cats_to_order = ["Round Robin", "1st Round",'2nd Round','3rd Round','4th Round','Quarterfinals', 'Semifinals', 'The Final']
    covered_type = CategoricalDtype(categories=cats_to_order, ordered=True)
    df['Round'] = df['Round'].cat.reorder_categories(cats_to_order, ordered=True)
    df["Round"] = df["Round"].cat.codes
    
    # Rimozione colonne influenti
    df.drop(["Location", "ATP"], axis =1, inplace=True)
    
    # Encoding Nome tornei
    lb_make = LabelEncoder()
    df["Tournament"] = lb_make.fit_transform(df["Tournament"])
    df["target"] = 0
    
    return df

# %% [markdown]
# # Funzioni per Swap righe

# %%
def swap (a,b):
    c=a
    a=b
    b=c
    return a,b

def swapP1P2 (row):
    copy = row.copy()
    swapCol=['Player1', 'Player2', 'P1_Rank', 'P2_Rank', 'P1_Pts', 'P2_Pts', 'P1_S1', 'P2_S1', 'P1_S2', 'P2_S2', 'P1_S3', 'P2_S3', 'P1_S4', 'P2_S4', 'P1_S5', 'P2_S5',
       'P1_sets', 'P2_sets', 'P1_B365', 'P2_B365', 'P1_EX', 'P2_EX', 'P1_LB', 'P2_LB', 'P1_PS', 'P2_PS', 'P1_Max', 'P2_Max', 'P1_Avg', 'P2_Avg']
    
    for i in range(0, int(len(swapCol)/2)):
        index=i*2
        aa = swapCol[index]
        bb = swapCol[index+1]
        copy[aa],copy[bb] = swap(copy[aa],copy[bb])
        copy["target"] = np.where (copy["target"] == 0, 1, 0)
        
    return copy
        

def randomSwap(df):
    maxRow = df.shape[0]
    for i in range(0,1000):
        pos = np.random.randint(0,maxRow)
        df.loc[pos] = swapP1P2(df.loc[pos])

# %% [markdown]
# # Prima prova applicazione modello

# %%
# Carico il dataset
df1 = loadDataset("2016")

# Mi ricordo come i giocatori vengono encodati
playerEncode = playEncode(df1)

# Formatto il dataset
df_v1 = generalFormatting(df1, playerEncode)
randomSwap(df_v1)

# %%
df_v1.head()
# Out:
#    Tournament       Date  Series  Round  Player1  Player2  P1_Rank  P2_Rank  \
# 0          15 2016-01-04       0      1      106      297     28.0     15.0
# 1          15 2016-01-04       0      1      111      210     69.0    129.0
# 2          15 2016-01-04       0      1       50      264    277.0    231.0
# 3          15 2016-01-04       0      1      220       13     60.0     51.0
# 4          15 2016-01-05       0      1      279      272     16.0     37.0
#
#    P1_Pts  P2_Pts  ...  Court_Outdoor  Surface_Clay  Surface_Grass  \
# 0  1360.0  2145.0  ...              1             0              0
# 1   719.0   459.0  ...              1             0              0
# 2   185.0   225.0  ...              1             0              0
# 3   782.0   817.0  ...              1             0              0
# 4  1880.0  1105.0  ...              1             0              0
#
#    Surface_Hard  Comment_Completed  Comment_Retired  Comment_Walkover  \
# 0             1                  1                0                 0
# 1             1                  1                0                 0
# 2             1                  1                0                 0
# 3             1                  1                0                 0
# 4             1                  1                0                 0
#
#    Best of_3  Best of_5  target
# 0          1          0       0
# 1          1          0       0
# 2          1          0       0
# 3          1          0       1
# 4          1          0       0
#
# [5 rows x 45 columns]

# %% [markdown]
#  # Applicazione modello stupido
# In questo modello diciamo che il giocatore più forte, ovvero quello che in classifica ha il numero più basso, vincerà sempre

# %%
y_test = df_v1["target"]
y_pred = []
for i in range(0,df_v1.shape[0]):
    y_pred.append(np.where(df_v1.loc[i,"P1_Rank"] < df_v1.loc[i,"P2_Rank"], 0, 1))
    
print("Accuracy score: ", accuracy_score(y_true = y_test, y_pred=y_pred))
# Out:
# Accuracy score:  0.6690784463061691

# %% [markdown]
# Notiamo che il modello è preciso al ~ 67% delle previsioni

# %% [markdown]
# # Creazione di nuove feature

# %% [markdown]
# ## Rateo vittorie fra giocatori nell'anno precedente

# %%
# Crea una matrice di Giocatore X Giocatore segnando quante volte uno a vinto contro un altro
def playerDf(df_old, df_new):
    playerList=set(df_old["Winner"]) | set(df_old["Loser"]) | set(df_new["Winner"]) | set(df_new["Loser"]) # Trovo tutti i giocatori singoli
    
    newDf= pd.DataFrame(data = 0, index=playerList, columns=playerList) # Creo un dataframe per vedere chi vince con chi
    
    winLoseDf = df_old[["Winner","Loser"]] # Per popolarlo prendo chi vince e chi perde
    
    for index, row in winLoseDf.iterrows():       
        newDf.loc[row["Winner"],row["Loser"]]+=1
        
        
    return newDf

# %%
# Mi serve per calcore il rateo di vittoria di un giocatore, se i giocatori non hanno giocato è 0.5
def rateo(p1, p2, wl):
    if wl.loc[p1, p2] == 0 and wl.loc[p2, p1] == 0:
        return 0.5
    else:
        return wl.loc[p1, p2] / (wl.loc[p1, p2]+wl.loc[p2,p1])

# %%
df2 = loadDataset("2017")

# %%
# Matrice con i giocatori dell'anno scelto ed il precedente
wl = playerDf(df1,df2)

# %%
df2["P1_WinRateo"] = 0
df2["P2_WinRateo"] = 0

for index, row in df2.iterrows():
    df2.loc[index,"P1_WinRateo"] = rateo(row["Winner"],row["Loser"],wl)
    df2.loc[index, "P2_WinRateo"] = rateo(row["Loser"],row["Winner"],wl)
    # print(row["P1_WinRateo"], row["P2_WinRateo"])

df2
# Out:
#       ATP  Location              Tournament       Date       Series    Court  \
# 0       1  Brisbane  Brisbane International 2017-01-01       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International 2017-01-02       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International 2017-01-02       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International 2017-01-02       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International 2017-01-02       ATP250  Outdoor
# ...   ...       ...                     ...        ...          ...      ...
# 2628   67    London             Masters Cup 2017-11-17  Masters Cup   Indoor
# 2629   67    London             Masters Cup 2017-11-17  Masters Cup   Indoor
# 2630   67    London             Masters Cup 2017-11-18  Masters Cup   Indoor
# 2631   67    London             Masters Cup 2017-11-18  Masters Cup   Indoor
# 2632   67    London             Masters Cup 2017-11-19  Masters Cup   Indoor
#
#      Surface        Round  Best of       Winner  ...   LBW   LBL    PSW   PSL  \
# 0       Hard    1st Round        3  Thompson J.  ...  1.30  3.50   1.31  3.73
# 1       Hard    1st Round        3     Mahut N.  ...  1.53  2.50   1.58  2.52
# 2       Hard    1st Round        3    Ferrer D.  ...  2.00  1.80   2.10  1.81
# 3       Hard    1st Round        3    Edmund K.  ...  1.40  3.00   1.42  3.09
# 4       Hard    1st Round        3  Dimitrov G.  ...  1.40  3.00   1.41  3.13
# ...      ...          ...      ...          ...  ...   ...   ...    ...   ...
# 2628    Hard  Round Robin        3    Goffin D.  ...  2.00  1.80   2.13  1.80
# 2629    Hard  Round Robin        3  Dimitrov G.  ...  1.22  4.33   1.24  4.57
# 2630    Hard   Semifinals        3    Goffin D.  ...  7.50  1.08  10.37  1.08
# 2631    Hard   Semifinals        3  Dimitrov G.  ...  1.40  2.75   1.44  3.07
# 2632    Hard    The Final        3  Dimitrov G.  ...  1.36  3.25   1.37  3.48
#
#        MaxW  MaxL  AvgW  AvgL  P1_WinRateo  P2_WinRateo
# 0      1.33  3.90  1.29  3.50     0.500000     0.500000
# 1      1.59  2.55  1.54  2.43     0.500000     0.500000
# 2      2.15  1.82  2.01  1.77     0.500000     0.500000
# 3      1.42  3.25  1.37  3.01     1.000000     0.000000
# 4      1.46  3.13  1.41  2.85     0.666667     0.333333
# ...     ...   ...   ...   ...          ...          ...
# 2628   2.15  1.91  2.05  1.79     0.500000     0.500000
# 2629   1.29  4.57  1.23  4.25     0.000000     1.000000
# 2630  10.37  1.12  8.45  1.08     0.000000     1.000000
# 2631   1.45  3.20  1.40  2.95     0.500000     0.500000
# 2632   1.45  3.60  1.36  3.24     0.500000     0.500000
#
# [2633 rows x 42 columns]
